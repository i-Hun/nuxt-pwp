# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pymc3 as pm
import pyreadstat
# %matplotlib inline

# %%
ess, _ = pyreadstat.read_sav('/Users/hun/Downloads/ESS6MDHe02.3/ESS6-big.sav')

ess.head()
# Out:
#   cntry      ESS6_id ESS6_reg NUTS1 NUTS2 NUTS3  essround  tvtot  tvpol  \
# 0    AL  AL000000001     AL05                         6.0    7.0    6.0
# 1    AL  AL000000002     AL08                         6.0    7.0    2.0
# 2    AL  AL000000003     AL10                         6.0    4.0    0.0
# 3    AL  AL000000004     AL05                         6.0    0.0    NaN
# 4    AL  AL000000005     AL07                         6.0    6.0    2.0
#
#    ppltrst     ...       c_gii_2012  c_indlib_2012  c_elect_2012  \
# 0      5.0     ...            0.251        67.7469           NaN
# 1      0.0     ...            0.251        67.7469           NaN
# 2      5.0     ...            0.251        67.7469           NaN
# 3     10.0     ...            0.251        67.7469           NaN
# 4      5.0     ...            0.251        67.7469           NaN
#
#    c_dis_rel_2012  c_lesys_2012  c_lbic_2012  c_ihsrate_2011  c_ticpi_2012  \
# ...

# %%
ess.shape
# Out:
# (54673, 645)

# %% [markdown]
# * Belong to minority ethnic group in country (`blgetmg`)
# * discrimination of respondent's group: colour or race (`dscrrce`)
# * discrimination of respondent's group: nationality (`dscrntn`)
# * discrimination of respondent's group: ethnic group (`dscretn`)
# * important that people are treated equally and have equal opportunities (`ipeqopt`)
# * Ethnolinguistic Fractionalisation
# * Important to understand different people
# * Important to follow traditions and customs
# * Age of respondent, calculated
# * Gender
# * Number of people living regularly as member of household
# * The rights of minority groups are protected
# * The courts treat everyone the same
# * In country the rights of minority groups are protected
# * Born in country
# * Father born in country
# * Mother born in country
# * What year you first came to live in country
# * Allow many/few immigrants of same race/ethnic group as majority
# * Allow many/few immigrants of different race/ethnic group from majority

# %%
ess.columns
# Out:
# Index(['cntry', 'ESS6_id', 'ESS6_reg', 'NUTS1', 'NUTS2', 'NUTS3', 'essround',
#        'tvtot', 'tvpol', 'ppltrst',
#        ...
#        'c_gii_2012', 'c_indlib_2012', 'c_elect_2012', 'c_dis_rel_2012',
#        'c_lesys_2012', 'c_lbic_2012', 'c_ihsrate_2011', 'c_ticpi_2012',
#        'c_hcide_2012', 'c_pris_2012'],
#       dtype='object', length=645)
